# %%
#pandas ---> Pandas is an open source library that is used for handle data manipulation.

# %%
#Data Structure of pandas -->
# 1.) Series--> It is one-dimensional array. It shows only values not column name.
# 2.) DataFrame --> It is multi-dimensional

# %%
import pandas as pd

# %% [markdown]
# 1.)Series

# %%
a = pd.Series([1, 45, 78, 90])
print(a)
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %% [markdown]
# 2. DataFrame

# %%
a={
    "ID":[1,2,3],
    "Name":['sam','raj','aman'],
    "Section":['A','B','C'],
}

# %%
df=pd.DataFrame(a)
df
# Out:
#    ID  Name Section
# 0   1   sam       A
# 1   2   raj       B
# 2   3  aman       C

# %% [markdown]
# How to export our data

# %%
df.to_csv('student_of_advance.csv',index=False)

# %% [markdown]
# How to import data

# %%
pd.read_csv('student_of_advance.csv')
# Out:
#    ID  Name Section
# 0   1   sam       A
# 1   2   raj       B
# 2   3  aman       C

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/placement - placement.csv")

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p=df.dtypes
p
# Out:
# ID          int64
# Name       object
# Section    object
# dtype: object

# %%
df.isnull().sum() # for check missing values.
# Out:
# ID         0
# Name       0
# Section    0
# dtype: int64

# %%
df.dropna() #for remove missing row
# Out:
#    ID  Name Section
# 0   1   sam       A
# 1   2   raj       B
# 2   3  aman       C

# %%
import pandas as pd

# # Example DataFrame
# df = pd.DataFrame([[1, 2], [3, 4]])

# Get the number of axes (dimensions)
i = df.ndim
print(i)
# Out:
# 2

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]
